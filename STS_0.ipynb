# %% [markdown]
# # STS Artificial Intelligence algorithm to allocate students in routes:

# %% [markdown]
# ## Libraries:

# %% [markdown]
# ### Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Folium

# %%
import folium

# %%
# Setting up Map:
m = folium.Map(location=sts, zoom_start=15, tiles='OpenStreetMap')

# %%
# Locations:
STS = [4.710664, -74.124992]
Bibiana = (4.715106, -74.118673)
Adriana = [4.722397, -74.128538]
Mafe = [4.713849, -74.123228]
David = [4.739318, -74.057423]
Viviana = [4.711273, -74.142623]
Diego_Torres = [4.731056, -74.281891]
Pedro_Alonso = [4.744045, -74.077286]
Luz = [4.906463, -74.103741]

# %%
# Adding locations to Map:
folium.Marker(location = Bibiana, tooltip='Bibiana Bernal').add_to(m)
folium.Marker(location = Viviana, tooltip='Viviana Bustos').add_to(m)
folium.Marker(location = David, tooltip='David Zambrano').add_to(m)
folium.Marker(location = Mafe, tooltip='Maria Fernanda').add_to(m)
folium.Marker(location = Adriana, tooltip='Adriana').add_to(m)
folium.Marker(location = Diego_Torres, tooltip='Diego Torres').add_to(m)
folium.Marker(location = Pedro_Alonso, tooltip='Pedro Alonso').add_to(m)
folium.Marker(location = Luz, tooltip='Luz').add_to(m)
folium.Marker(location = STS, tooltip='School Touring Service').add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_4c5d46e14c9f45e085392cb78a60794e%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4c5d46e14c9f45e085392cb78a60794e%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_4c5d46e14c9f45e085392cb78a60794e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_4c5d46e14c9f45e085392cb78a60794e%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B4.710664%2C%20-74.124992%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_14741f42c9084bc29f383727c98ece65%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20% ...

# %% [markdown]
# ### Google

# %%
import requests

# %%
API_KEY = ''

# %%
direccion = 'Carrera 55 # 152b 68 Bogota Colombia'
params = {'key':API_KEY, 
          'address': direccion
          }

# %%
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
response = requests.get(base_url, params = params)
response.json()
# Out:
# {'results': [{'address_components': [{'long_name': '152b-68',
#      'short_name': '152b-68',
#      'types': ['street_number']},
#     {'long_name': 'Carrera 55', 'short_name': 'Cra. 55', 'types': ['route']},
#     {'long_name': 'Reservas de La Colina',
#      'short_name': 'Reservas de La Colina',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Suba',
#      'short_name': 'Suba',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Bogotá',
#      'short_name': 'Bogotá',
#      'types': ['locality', 'political']},
#     {'long_name': 'Bogotá',
#      'short_name': 'Bogotá',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Colombia',
#      'short_name': 'CO',
#      'types': ['country', 'political']},
#     {'long_name': '111156', 'short_name': '111156', 'types': ['postal_code']}],
#    'formatted_address': 'Cra. 55 #152b-68, Suba, Bogotá, Colombia',
#    'geometry': {'location': {'lat': 4.7390935, 'lng': -74.056382},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 4.740442480291502,
#       'lng': -74.0550330197085},
#      'southwest': {'lat': 4.737744519708498, 'lng': -74.05773098029151}}},
#    'place_id': 'ChIJ9cNZTgyFP44R94-SiOgznBs',
#    'types': ['street_address']}],
#  'status': 'OK'}

# %%
latitud = response.json()['results'][0]['geometry']['location']['lat']
longitud = response.json()['results'][0]['geometry']['location']['lng']
[latitud, longitud]
# Out:
# [4.7390935, -74.056382]

# %% [markdown]
# ## Adding coordinates:

# %%
df = pd.read_excel('/content/sts AI project.xlsx')
#df

# %%
df['residence'] = df['Residencia'].astype(str) + ' Bogota Colombia'

# %%
residence = df["residence"].to_numpy()
# residence

# %%
latitudes = []
longitudes = []

# %%
for i in residence:
  direccion = i
  params = {'key':API_KEY, 
          'address': direccion}
  response = requests.get(base_url, params = params)
  #response.json()
  try:
    latitud = response.json()['results'][0]['geometry']['location']['lat']
    longitud = response.json()['results'][0]['geometry']['location']['lng']
    print(i, latitud, longitud)
    latitudes.append(latitud)
    longitudes.append(longitud)
  except:
    print(i + " not found")
    latitudes.append('not found')
    longitudes.append('not found')
# Out:
# CLLE 81 # 113 46 Bogota Colombia 4.7226573 -74.1188679
# CRA 116 B # 80 51  Bogota Colombia 4.725364799999999 -74.1230532
# CLL 82 # 112F - 10  Bogota Colombia 4.7220662 -74.11650809999999
# CLLE 80 A # 116 B 23  Bogota Colombia 4.7260501 -74.1232425
# CLLE 83 A # 116 A 85  Bogota Colombia 4.7271399 -74.12036669999999
# CLLE 83 A # 116 A 72 Bogota Colombia 4.7277943 -74.11994829999999
# CRA 118 # 89 B - 35  Bogota Colombia 4.7327489 -74.1179399
# CLLE 81 # 114-50  Bogota Colombia 4.7241476 -74.1191685
# CRA 115 A # 89 B 20 Bogota Colombia 4.7295709 -74.1138454
# CLLE 81 # 115 15 Bogota Colombia 4.7239944 -74.12078439999999
# CRA 114 # 80  51  Bogota Colombia 4.7228366 -74.1209799
# CLLE 89 A # 116 A 35 Bogota Colombia 4.7293426 -74.1173792
# CLLE 83 A # 114 24 Bogota Colombia 4.7256978 -74.1171222
# CLLE 81 # 114 50 Bogota Colombia 4.7241476 -74.1191685
# CLLE 83 A # 116 A 85 Bogota Colombia 4.7271399 -74.12036669999999
# CLLE 83 A # 118 29  Bogota Colombia 4.728197199999999 -74.12050049999999
# CLLE 81 # 114 50 Bogota Colombia 4.7241476 -74.1191685
# CLLE 81 # 114 50 Bogota Colombia 4.7241476 -74.1191685
# CLLE 81 # 115 25 Bogota Colombia 4.7240967 -74.1217162
# CLLE 83 A # 114-99 Bogota Colombia 4.7260724 -74.1180926
# CRA 119 # 80 22 Bogota Colombia 4.7263958 -74.12372549999999
# CLLE 81 # 114 25  Bogota Colombia 4.7232816 -74.12014800000001
# CRA 118 # 89 B 35 Bogota Colombia 4.7327489 -74.1179399
# CRA 115 A # 89 B 20  Bogota Colombia 4.7295709 -74.1138454
# CLLE 81# 114-50  Bogota Colombia 4.7241476 -74.1191685
# CRA 118 # 83 A 45  Bogota Colombia 4.728748500000001 -74.1197626
# CLLE 81 # 115 25  Bogota Colombia 4.7240967 -74.1217162
# CLLE 81 # 113 39 Bogota Colombia 4.7223446 -74.1190754
# CRA 116 B # 80 51  Bogota Colombia 4.725364799999999 -74.1230532
# CRA 116 B # 80 51 Bogota Colombia 4.725364799999999 -74.1230532
# CLLE 83 A #115-07 Bogota Colombia 4.726234799999999 -74.11913369999999
# CLLE 83A # 115-92 Bogota Colombia 4.7270109 -74.118899
# CRA 113 # 83 A 42  Bogota Colombia 4.7244288 -74.1154542
# CRA 118 # 86 35  Bogota Colombia 4.7302554 -74.1186412
# CLLE 86 A # 112 G 21  Bogota Colombia 4.7255308 -74.1138794
# CLLE 86 A # 112 G 21  Bogota Colombia 4.7255308 -74.1138794
# CLLE 86 A # 112 G 21  Bogota Colombia 4.7255308 -74.1138794
# CRA 112 F # 80 85  Bogota Colombia 4.7209106 -74.1189966
# CLLE 86 # 103 D 45 Bogota Colombia 4.719378 -74.1108271
# CLLE 87 # 103-F 50  Bogota Colombia 4.7215998 -74.10829869999999
# CLLE 87 # 103 F 50 Bogota Colombia 4.7215998 -74.10829869999999
# CRA 118 # 86 20  Bogota Colombia 4.729618299999999 -74.1182341
# CRA 118 # 86 - 20  Bogota Colombia 4.729618299999999 -74.1182341
# CLLE 86 A# 112 G 21  Bogota Colombia 4.725298599999999 -74.1139571
# CRA 112 BIS # 81 51 Bogota Colombia 4.7211937 -74.1172292
# DG 89 A # 115 55 Bogota Colombia 4.727060199999999 -74.1155575
# DG 89 A # 115 55  Bogota Colombia 4.727060199999999 -74.1155575
# DG 89 B # 115 A 03 Bogota Colombia 4.7293478 -74.1144885
# CLLE 86 A # 112 C 21 Bogota Colombia 4.7254702 -74.1138581
# CLLE 86 A # 112 G 21 Bogota Colombia 4.7255308 -74.1138794
# CLLE 81 # 110 - 34  Bogota Colombia 4.7187667 -74.1157996
# CRA 112 BIS # 80 A 15 Bogota Colombia 4.720566499999999 -74.11813479999999
# CLLE 86 # 103D-24 Bogota Colombia 4.7192146 -74.1104519
# CLLE 87 # 103 C 50 Bogota Colombia 4.719878599999999 -74.1071948
# CRA 118 # 86 35  Bogota Colombia 4.7302554 -74.1186412
# CRA 113  # 81 58 Bogota Colombia 4.7225117 -74.1178978
# DG 85 # 85 30 Bogota Colombia 4.706842099999999 -74.0972237
# CRA 103 D # 82 31 Bogota Colombia 4.7167961 -74.1124528
# CRA 103 D # 82 55 Bogota Colombia 4.7170026 -74.1118142
# CLLE 88 # 89 A 30  Bogota Colombia 4.7107447 -74.09811839999999
# CLLE 80 # 102-64 Bogota Colombia 4.712562399999999 -74.1143893
# CLLE 87 # 103 D 31 Bogota Colombia 4.7215626 -74.1086948
# CRA 103 B # 82 48 Bogota Colombia 4.7152919 -74.1111609
# DG 86 A # 103D 22 Bogota Colombia 4.7210983 -74.1095181
# Cra 109 a # 81-71 Bogota Colombia 4.7180206 -74.1152214
# CRA 101 # 83 90 Bogota Colombia 4.7012211 -74.119765
# DG 86 A # 101 - 40 Bogota Colombia 4.7167455 -74.1073985
# CRA 102 # 86 A 46 Bogota Colombia 4.7174042 -74.107491
# DG 86 A # 101 40 Bogota Colombia 4.7167455 -74.1073985
# CLLE 93 # 72-20  Bogota Colombia 4.6973483 -74.0852391
# CLLE 94 # 72 A 96 Bogota Colombia 4.7011541 -74.08614659999999
# CRA 95 # 71 75 Bogota Colombia 4.6306144 -74.20097659999999
# CLLE 94 # 72 A 99 Bogota Colombia 4.7008618 -74.08728529999999
# CRA 70 C # 80 48 Bogota Colombia 4.6938847 -74.0853745
# CRA 71 D # 95 A 26 Bogota Colombia 4.696532299999999 -74.08272939999999
# CLLE 95 # 71 11  Bogota Colombia 4.694141699999999 -74.0819661
# CLLE 86 A # 69 T 81 Bogota Colombia 4.6932655 -74.08453589999999
# CRA 71 # 95 A 25 Bogota Colombia 4.710988599999999 -74.072092
# CLLE 95 # 71 75 Bogota Colombia 4.6959151 -74.0835951
# CRA 70 # 96 92 Bogota Colombia 4.6924473 -74.07738580000002
# CLLE 97 # 70 90 Bogota Colombia 4.693566199999999 -74.07818019999999

# %%
df['latitudes'] = latitudes
df['longitudes'] = longitudes

# %%
df['coordenadas']= list(zip(df.latitudes, df.longitudes))
#df

# %%
df_1 = df[df['RUTA ']==1]
df_2 = df[df['RUTA ']==2]
df_5 = df[df['RUTA ']==5]
df_25 = df[df['RUTA ']==25]

# %%
dict_of_locations_1 = pd.Series(df_1.coordenadas.values,index=df_1.Alumno).to_dict()
dict_of_locations_2 = pd.Series(df_2.coordenadas.values,index=df_2.Alumno).to_dict()
dict_of_locations_5 = pd.Series(df_5.coordenadas.values,index=df_5.Alumno).to_dict()
dict_of_locations_25 = pd.Series(df_25.coordenadas.values,index=df_25.Alumno).to_dict()

#dict_of_locations

# %%
# Setting up Map:
mapa_de_alumnos = folium.Map(location=STS, zoom_start=12, tiles='OpenStreetMap', width='90%', height='90%')

# %%
# Adding locations to Map:
for i in dict_of_locations_1:
  folium.Marker(location = dict_of_locations_1[i], tooltip=i).add_to(mapa_de_alumnos)
for i in dict_of_locations_2:
  folium.Marker(location = dict_of_locations_2[i], tooltip=i, icon=folium.Icon(color="red", icon="info-sign")).add_to(mapa_de_alumnos)
for i in dict_of_locations_5:
  folium.Marker(location = dict_of_locations_5[i], tooltip=i, icon=folium.Icon(color="green", icon="info-sign")).add_to(mapa_de_alumnos)
for i in dict_of_locations_25:
  folium.Marker(location = dict_of_locations_25[i], tooltip=i, icon=folium.Icon(color="pink", icon="info-sign")).add_to(mapa_de_alumnos)

# %%
# The Map:
mapa_de_alumnos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_808051802e38426a863c9b22c94941f1%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%2090.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%2090.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_808051802e38426a863c9b22c94941f1%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_808051802e38426a863c9b22c94941f1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_808051802e38426a863c9b22c94941f1%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B4.710664%2C%20-74.124992%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_63aa1732a6e54bd4b5fbf9c94d47a48e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20 ...

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 1000
